# %%
#=============TASK 1====================
import pandas as pd

# %%
df  = pd.read_csv("retail_sales_dataset.csv")

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 1000
# Columns: 9

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Transaction ID      int64
# Date                  str
# Customer ID           str
# Gender                str
# Age                 int64
# Product Category      str
# Quantity            int64
# Price per Unit      int64
# Total Amount        int64
# dtype: object

# %%
df["Product Category"].unique()
# Out:
# <StringArray>
# ['Beauty', 'Clothing', 'Electronics']
# Length: 3, dtype: str

# %%
print("Minimum Age:", df["Age"].min())
print("Maximum Age:", df["Age"].max())
# Out:
# Minimum Age: 18
# Maximum Age: 64

# %%
#========Task 3==========
print("Blank Cells:", df.isnull().sum().sum())
print("Duplicated Rows:", df.duplicated().sum())
# Out:
# Blank Cells: 0
# Duplicated Rows: 0

# %%
print("Minimum Quantity:", df["Quantity"].min())
print("Maximum Quantity:", df["Quantity"].max())
# Out:
# Minimum Quantity: 1
# Maximum Quantity: 4

# %%
print("Minimum Price:", df["Price per Unit"].min())
print("Maximum Price:", df["Price per Unit"].max())
# Out:
# Minimum Price: 25
# Maximum Price: 500

# %%
calculated_total = df["Quantity"] * df["Price per Unit"]
mismatches = (calculated_total != df["Total Amount"]).sum()
print("Amount Mismatches:", mismatches)
# Out:
# Amount Mismatches: 0

# %%
#================TASK 4=========================
print("Total Sales:", df["Total Amount"].sum())
# Out:
# Total Sales: 456000

# %%
print("Average Sale:", df["Total Amount"].mean())
# Out:
# Average Sale: 456.0

# %%
print("Minimum Sale:", df["Total Amount"].min())
# Out:
# Minimum Sale: 25

# %%
print("Maximum Sale:", df["Total Amount"].max())
# Out:
# Maximum Sale: 2000

# %%
print("Total Quantity Sold:", df["Quantity"].sum())
# Out:
# Total Quantity Sold: 2514

# %%
print("Average Customer Age:", df["Age"].mean())
# Out:
# Average Customer Age: 41.392

# %%
print("Youngest Customer:", df["Age"].min())
# Out:
# Youngest Customer: 18

# %%
print("Oldest Customer:", df["Age"].max())
# Out:
# Oldest Customer: 64

# %%
print("Total Transactions:", df["Transaction ID"].count())
# Out:
# Total Transactions: 1000

# %%
print("Unique Categories:", df["Product Category"].nunique())
# Out:
# Unique Categories: 3

# %%
#==============Task 6========================
print(df.groupby("Product Category")["Total Amount"].sum())
# Out:
# Product Category
# Beauty         143515
# Clothing       155580
# Electronics    156905
# Name: Total Amount, dtype: int64

# %%
print(df["Product Category"].unique())
# Out:
# <StringArray>
# ['Beauty', 'Clothing', 'Electronics']
# Length: 3, dtype: str

# %%
print(df.groupby("Product Category")["Quantity"].sum())
# Out:
# Product Category
# Beauty         771
# Clothing       894
# Electronics    849
# Name: Quantity, dtype: int64

# %%
print(df.groupby("Gender")["Total Amount"].sum())
# Out:
# Gender
# Female    232840
# Male      223160
# Name: Total Amount, dtype: int64

# %%
df["Age Group"] = df["Age"].apply(
    lambda age: "Young Adult" if age <= 25
    else "Adult" if age <= 40
    else "Senior Adult" if age <= 60
    else "Older Customer"
)

print(df.groupby("Age Group")["Total Amount"].sum())
# Out:
# Age Group
# Adult             144345
# Older Customer     33225
# Senior Adult      193880
# Young Adult        84550
# Name: Total Amount, dtype: int64
